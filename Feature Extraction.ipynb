# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from constants import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from helpers.solr_client import *
from helpers.fusion_client import *

solr = LTRSolrClient(COLLECTION_NAME)
signals_client = SignalsSolrClient(SIGNALS_COLLECTION_NAME, base_fq=SIGNALS_BASE_FQ)
fusion = FusionAPIClient('http://localhost:8764/api/apollo/apps/{}'.format(FUSION_APP_NAME))

# %%
print "# products:", solr.num_hits("*:*")
print "# click signals:", signals_client.num_hits("*:*")
# Out:
# # products: 1275077
# # click signals: 3273140

# %% [markdown]
# # Run Feature Extraction
# * Grab the N most recent signals from Solr. These serve as input queries to the Solr LTR feature extraction process.
# * Extract features for each row (per https://lucene.apache.org/solr/guide/7_0/learning-to-rank.html#extracting-features)
# * Save results as CSV to disk
# * Use Spark to parallelize, otherwise this will take forever

# %%
# Needed to ship dependent modules to spark cluster
from helpers.spark_utils import spark_add_py_module
import helpers

spark_add_py_module(spark, helpers)

# %%
from collections import Counter

def do_extract_features(tup):
    query_id, query, doc_id, solr_date = tup
    dt = solr_date_to_datetime(solr_date)
    
    results = fusion.search_query_pipeline(FUSION_QUERY_PIPELINE_NAME, COLLECTION_NAME, query, 
                                           rows=STAGE_A_TOP_N)
    
    feature_dictionary = None
    for doc in results['response']['docs']:
        feature_names, values = zip(
            *[featval.split('=') for featval in doc['[features]'].split(',')])
        vector = map(float, values)
        if not feature_dictionary:
            feature_dictionary = feature_names
        else:
            assert feature_dictionary == feature_names

        sample = [
            query_id,
            datetime_to_epoch_seconds(dt),
            query,
            str(doc['id']),
            int(str(doc['id']) == str(doc_id)),
        ]
        sample.extend(vector)

        yield sample
            
def tab_delimit(data):
    # ugly
    as_str = []
    for x in data:
        val = x
        if isinstance(x, unicode):
            val = x.encode('utf8')
        else:
            val = str(x)
        as_str.append(val)
    
    return "\t".join(as_str)

def get_feature_names():
    feature_names = [feature['name'] for feature in solr.get_features(FEATURE_STORE_NAME)]
    return feature_names

def save_feature_names(path):
    feature_names = get_feature_names()
    with open(os.path.join(path, 'feature_names.txt'), 'w') as f:
        f.write(json.dumps(feature_names))

# %% [markdown]
# ## Sample of Feature Extracton output for a single query

# %%
import seaborn as sns

def get_signal_query_object(query_text):
    for row in signals_client.get_most_recent_signals(10000, 
                                                      q=query_text,
                                                      fq="*:*"):
        return row
    return None


def get_single_query_results(query):
    """
    For testing only
    """
    row = get_signal_query_object(query)
    
    samples = do_extract_features((
        row[signals_client.schema.query_id_field_name], 
        row[signals_client.schema.query_field_name], 
        row[signals_client.schema.doc_id_field_name], 
        row[signals_client.schema.date_field_name]))
    
    df = pd.DataFrame([sample for sample in samples])    
    cols = ['query_id', 'date', 'query', 'doc_id', 'target']
    feature_names = get_feature_names()
    cols.extend(feature_names)
    df.columns = cols
    
    return df

df = get_single_query_results('ipad 2')
cm = sns.light_palette("green", as_cmap=True)
df.head(25).style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row0_col1 {
#             background-color:  #e5ffe5;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row0_col4 {
#             background-color:  #e5ffe5;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row0_col5 {
#             background-color:  #5ab25a;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row0_col6 {
#             background-color:  #5ab25a;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row0_col7 {
#             background-color:  #289628;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row0_col8 {
#             background-color:  #e5ffe5;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row0_col9 {
#             background-color:  #dcfadc;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row0_col10 {
#             background-color:  #048204;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row0_col11 {
#             background-color:  #008000;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row0_col12 {
#             background-color:  #e5ffe5;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row0_col13 {
#             background-color:  #e5ffe5;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row0_col14 {
#             background-color:  #e5ffe5;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row0_col15 {
#             background-color:  #168c16;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row0_col16 {
#             background-color:  #008000;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row0_col17 {
#             background-color:  #6cbc6c;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row0_col18 {
#             background-color:  #50ac50;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row1_col4 {
#             background-color:  #008000;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row1_col5 {
#             background-color:  #5ab25a;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row1_col6 {
#             background-color:  #5ab25a;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row1_col7 {
#             background-color:  #289628;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row1_col8 {
#             background-color:  #e5ffe5;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row1_col9 {
#             background-color:  #dcfadc;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row1_col10 {
#             background-color:  #048204;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row1_col11 {
#             background-color:  #acdfac;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row1_col12 {
#             background-color:  #e5ffe5;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row1_col13 {
#             background-color:  #e5ffe5;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row1_col14 {
#             background-color:  #e5ffe5;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row1_col15 {
#             background-color:  #0b860b;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row1_col16 {
#             background-color:  #48a848;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row1_col17 {
#             background-color:  #6cbc6c;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row1_col18 {
#             background-color:  #50ac50;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row2_col1 {
#             background-color:  #e5ffe5;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row2_col4 {
#             background-color:  #e5ffe5;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row2_col5 {
#             background-color:  #5ab25a;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row2_col6 {
#             background-color:  #5ab25a;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row2_col7 {
#             background-color:  #289628;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row2_col8 {
#             background-color:  #e5ffe5;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row2_col9 {
#             background-color:  #dcfadc;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row2_col10 {
#             background-color:  #048204;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row2_col11 {
#             background-color:  #ade0ad;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row2_col12 {
#             background-color:  #b5e4b5;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row2_col13 {
#             background-color:  #a3daa3;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row2_col14 {
#             background-color:  #e5ffe5;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row2_col15 {
#             background-color:  #0b860b;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row2_col16 {
#             background-color:  #76c176;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row2_col17 {
#             background-color:  #4caa4c;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row2_col18 {
#             background-color:  #3ca13c;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row3_col1 {
#             background-color:  #e5ffe5;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row3_col4 {
#             background-color:  #e5ffe5;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row3_col5 {
#             background-color:  #5ab25a;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row3_col6 {
#             background-color:  #5ab25a;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row3_col7 {
#             background-color:  #289628;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row3_col8 {
#             background-color:  #e5ffe5;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row3_col9 {
#             background-color:  #dcfadc;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row3_col10 {
#             background-color:  #048204;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row3_col11 {
#             background-color:  #cff3cf;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row3_col12 {
#             background-color:  #defbde;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row3_col13 {
#             background-color:  #dcfadc;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row3_col14 {
#             background-color:  #a4dba4;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row3_col15 {
#             background-color:  #168c16;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row3_col16 {
#             background-color:  #a2daa2;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row3_col17 {
#             background-color:  #2a972a;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row3_col18 {
#             background-color:  #289628;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row4_col1 {
#             background-color:  #e5ffe5;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row4_col4 {
#             background-color:  #e5ffe5;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row4_col5 {
#             background-color:  #5ab25a;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row4_col6 {
#             background-color:  #5ab25a;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row4_col7 {
#             background-color:  #289628;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row4_col8 {
#             background-color:  #e5ffe5;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row4_col9 {
#             background-color:  #dcfadc;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row4_col10 {
#             background-color:  #048204;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row4_col11 {
#             background-color:  #d1f4d1;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row4_col12 {
#             background-color:  #b8e6b8;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row4_col13 {
#             background-color:  #9ed79e;
#         }    #T_6e6e8600_305f_11e8_8cfc_8c85904df2c9row4_col14 {
#             background-color:  #008000;
#         }    #T_6e6e8600_305f_11e8_8cf

# %% [markdown]
# # Extract Features

# %%
import shutil

try:
    shutil.rmtree(FEATURE_VECTORS_PATH)
except:
    pass

signals_to_vectorize = (
    (row[signals_client.schema.query_id_field_name], 
     row[signals_client.schema.query_field_name], 
     row[signals_client.schema.doc_id_field_name], 
     row[signals_client.schema.date_field_name])
    for row in signals_client.get_most_recent_signals(SIGNALS_FEATURE_EXTRACTION_LIMIT, 
                                                      fq="*:*", 
                                                      dedup=True)
)

(
    spark.sparkContext
    .parallelize(signals_to_vectorize)
    .flatMap(do_extract_features)
    .map(tab_delimit)
    .saveAsTextFile(FEATURE_VECTORS_PATH)
)        

save_feature_names(FEATURE_VECTORS_PATH)
# Out:
# Fetched 500 signal rows from Solr
# Fetched 1000 signal rows from Solr
# Fetched 1500 signal rows from Solr
# Fetched 2000 signal rows from Solr
# Fetched 2500 signal rows from Solr
# Fetched 3000 signal rows from Solr
# Fetched 3500 signal rows from Solr
# Fetched 4000 signal rows from Solr
# Fetched 4500 signal rows from Solr
# Fetched 5000 signal rows from Solr
